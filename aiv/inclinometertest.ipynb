# %%
import matplotlib.pyplot as plt
import statistics as stats
import datetime
import matplotlib.dates as mdates
import pandas as pd

# %%
azencoder = []
x = []
y = []
azavg = []
xavg = []
yavg = []
xrms = []
yrms = []

az=270.0
dataframe = pd.read_excel('/scratch/bstalder/inclinometer test/TMA270.xls')
xmeas = list(dataframe['X-Axis Value'])
ymeas = list(dataframe['Y-Axis Value'])


for index, element in enumerate(list(dataframe['X-Axis Value'])):
    azencoder.append(az)
    x.append(float(element.replace('"','')))
    xmeas[index] = float(element.replace('"',''))
                                
for index, element in enumerate(list(dataframe['Y-Axis Value'])):
    y.append(float(element.replace('"','')))
    ymeas[index] = float(element.replace('"',''))

azavg.append(az)
xavg.append(stats.mean(xmeas))
yavg.append(stats.mean(ymeas))
xrms.append(stats.stdev(xmeas))
yrms.append(stats.stdev(ymeas))
    
az=180.0
dataframe = pd.read_excel('/scratch/bstalder/inclinometer test/TMA180.xls')
xmeas = list(dataframe['X-Axis Value'])
ymeas = list(dataframe['Y-Axis Value'])


for index, element in enumerate(list(dataframe['X-Axis Value'])):
    azencoder.append(az)
    x.append(float(element.replace('"','')))
    xmeas[index] = float(element.replace('"',''))
                                
for index, element in enumerate(list(dataframe['Y-Axis Value'])):
    y.append(float(element.replace('"','')))
    ymeas[index] = float(element.replace('"',''))

azavg.append(az)
xavg.append(stats.mean(xmeas))
yavg.append(stats.mean(ymeas))
xrms.append(stats.stdev(xmeas))
yrms.append(stats.stdev(ymeas))

az=90.0
dataframe = pd.read_excel('/scratch/bstalder/inclinometer test/TMA90.xls')
xmeas = list(dataframe['X-Axis Value'])
ymeas = list(dataframe['Y-Axis Value'])


for index, element in enumerate(list(dataframe['X-Axis Value'])):
    azencoder.append(az)
    x.append(float(element.replace('"','')))
    xmeas[index] = float(element.replace('"',''))
                                
for index, element in enumerate(list(dataframe['Y-Axis Value'])):
    y.append(float(element.replace('"','')))
    ymeas[index] = float(element.replace('"',''))

azavg.append(az)
xavg.append(stats.mean(xmeas))
yavg.append(stats.mean(ymeas))
xrms.append(stats.stdev(xmeas))
yrms.append(stats.stdev(ymeas))

az=0.0
dataframe = pd.read_excel('/scratch/bstalder/inclinometer test/TMA0.xls')
xmeas = list(dataframe['X-Axis Value'])
ymeas = list(dataframe['Y-Axis Value'])


for index, element in enumerate(list(dataframe['X-Axis Value'])):
    azencoder.append(az)
    x.append(float(element.replace('"','')))
    xmeas[index] = float(element.replace('"',''))
                                
for index, element in enumerate(list(dataframe['Y-Axis Value'])):
    y.append(float(element.replace('"','')))
    ymeas[index] = float(element.replace('"',''))

azavg.append(az)
xavg.append(stats.mean(xmeas))
yavg.append(stats.mean(ymeas))
xrms.append(stats.stdev(xmeas))
yrms.append(stats.stdev(ymeas))

az=-90.0
dataframe = pd.read_excel('/scratch/bstalder/inclinometer test/TMA-90.xls')
xmeas = list(dataframe['X-Axis Value'])
ymeas = list(dataframe['Y-Axis Value'])


for index, element in enumerate(list(dataframe['X-Axis Value'])):
    azencoder.append(az)
    x.append(float(element.replace('"','')))
    xmeas[index] = float(element.replace('"',''))
                                
for index, element in enumerate(list(dataframe['Y-Axis Value'])):
    y.append(float(element.replace('"','')))
    ymeas[index] = float(element.replace('"',''))

azavg.append(az)
xavg.append(stats.mean(xmeas))
yavg.append(stats.mean(ymeas))
xrms.append(stats.stdev(xmeas))
yrms.append(stats.stdev(ymeas))

az=-180.0
dataframe = pd.read_excel('/scratch/bstalder/inclinometer test/TMA-180.xls')
xmeas = list(dataframe['X-Axis Value'])
ymeas = list(dataframe['Y-Axis Value'])


for index, element in enumerate(list(dataframe['X-Axis Value'])):
    azencoder.append(az)
    x.append(float(element.replace('"','')))
    xmeas[index] = float(element.replace('"',''))
                                
for index, element in enumerate(list(dataframe['Y-Axis Value'])):
    y.append(float(element.replace('"','')))
    ymeas[index] = float(element.replace('"',''))

azavg.append(az)
xavg.append(stats.mean(xmeas))
yavg.append(stats.mean(ymeas))
xrms.append(stats.stdev(xmeas))
yrms.append(stats.stdev(ymeas))

az=-90.0
dataframe = pd.read_excel('/scratch/bstalder/inclinometer test/TMA-90reverse.xls')
xmeas = list(dataframe['X-Axis Value'])
ymeas = list(dataframe['Y-Axis Value'])


for index, element in enumerate(list(dataframe['X-Axis Value'])):
    azencoder.append(az)
    x.append(float(element.replace('"','')))
    xmeas[index] = float(element.replace('"',''))
                                
for index, element in enumerate(list(dataframe['Y-Axis Value'])):
    y.append(float(element.replace('"','')))
    ymeas[index] = float(element.replace('"',''))

azavg.append(az)
xavg.append(stats.mean(xmeas))
yavg.append(stats.mean(ymeas))
xrms.append(stats.stdev(xmeas))
yrms.append(stats.stdev(ymeas))

az=0.0
dataframe = pd.read_excel('/scratch/bstalder/inclinometer test/TMA0reverse.xls')
xmeas = list(dataframe['X-Axis Value'])
ymeas = list(dataframe['Y-Axis Value'])


for index, element in enumerate(list(dataframe['X-Axis Value'])):
    azencoder.append(az)
    x.append(float(element.replace('"','')))
    xmeas[index] = float(element.replace('"',''))
                                
for index, element in enumerate(list(dataframe['Y-Axis Value'])):
    y.append(float(element.replace('"','')))
    ymeas[index] = float(element.replace('"',''))

azavg.append(az)
xavg.append(stats.mean(xmeas))
yavg.append(stats.mean(ymeas))
xrms.append(stats.stdev(xmeas))
yrms.append(stats.stdev(ymeas))

az=90.0
dataframe = pd.read_excel('/scratch/bstalder/inclinometer test/TMA90reverse.xls')
xmeas = list(dataframe['X-Axis Value'])
ymeas = list(dataframe['Y-Axis Value'])


for index, element in enumerate(list(dataframe['X-Axis Value'])):
    azencoder.append(az)
    x.append(float(element.replace('"','')))
    xmeas[index] = float(element.replace('"',''))
                                
for index, element in enumerate(list(dataframe['Y-Axis Value'])):
    y.append(float(element.replace('"','')))
    ymeas[index] = float(element.replace('"',''))

azavg.append(az)
xavg.append(stats.mean(xmeas))
yavg.append(stats.mean(ymeas))
xrms.append(stats.stdev(xmeas))
yrms.append(stats.stdev(ymeas))

az=180.0
dataframe = pd.read_excel('/scratch/bstalder/inclinometer test/TMA180reverse.xls')
xmeas = list(dataframe['X-Axis Value'])
ymeas = list(dataframe['Y-Axis Value'])


for index, element in enumerate(list(dataframe['X-Axis Value'])):
    azencoder.append(az)
    x.append(float(element.replace('"','')))
    xmeas[index] = float(element.replace('"',''))
                                
for index, element in enumerate(list(dataframe['Y-Axis Value'])):
    y.append(float(element.replace('"','')))
    ymeas[index] = float(element.replace('"',''))

azavg.append(az)
xavg.append(stats.mean(xmeas))
yavg.append(stats.mean(ymeas))
xrms.append(stats.stdev(xmeas))
yrms.append(stats.stdev(ymeas))

az=207.0
dataframe = pd.read_excel('/scratch/bstalder/inclinometer test/TMA207reverse.xls')
xmeas = list(dataframe['X-Axis Value'])
ymeas = list(dataframe['Y-Axis Value'])


for index, element in enumerate(list(dataframe['X-Axis Value'])):
    azencoder.append(az)
    x.append(float(element.replace('"','')))
    xmeas[index] = float(element.replace('"',''))
                                
for index, element in enumerate(list(dataframe['Y-Axis Value'])):
    y.append(float(element.replace('"','')))
    ymeas[index] = float(element.replace('"',''))

azavg.append(az)
xavg.append(stats.mean(xmeas))
yavg.append(stats.mean(ymeas))
xrms.append(stats.stdev(xmeas))
yrms.append(stats.stdev(ymeas))
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %%
print(yrms)
# Out:
# [0.6430158534243944, 0.08091315576289283, 0.0, 0.0, 0.20203050891044233, 0.054809503123573744, 0.08369039151929576, 0.09071147352221501, 0.0, 0.0, 0.09570362413968095]

# %%
plt.scatter(azavg,xavg,label='Average X measurements vs. Azimuth')
plt.errorbar(azavg,xavg,yerr=xrms,fmt="o")
plt.rcParams['figure.figsize'] = [14, 8]
#plt.gcf().autofmt_xdate()
#myFmt = mdates.DateFormatter('%H:%M')
#plt.gca().xaxis.set_major_formatter(myFmt)
plt.xlabel('Az encoder')
plt.ylabel('X tilt')
plt.title('inclinometer measurments')
plt.legend()
plt.show()

# %%
plt.scatter(azavg,yavg, label='Average Y measurements vs. Azimuth')
plt.errorbar(azavg,yavg,yerr=yrms,fmt="o")
plt.rcParams['figure.figsize'] = [14, 8]
#plt.gcf().autofmt_xdate()
#myFmt = mdates.DateFormatter('%H:%M')
#plt.gca().xaxis.set_major_formatter(myFmt)
plt.xlabel('Az encoder')
plt.ylabel('Y tilt')
plt.title('inclinometer measurments')
plt.legend()
plt.show()
